# %%
# !pip install pandas
# !pip install scikit-learn
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# Requirement already satisfied: pandas in /home/swaraj/myenv/lib/python3.14/site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in /home/swaraj/myenv/lib/python3.14/site-packages (from pandas) (2.4.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/swaraj/myenv/lib/python3.14/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /home/swaraj/myenv/lib/python3.14/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /home/swaraj/myenv/lib/python3.14/site-packages (from scikit-learn) (2.4.4)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
# Requirement already satisfied: joblib>=1.3.0 in /home/swaraj/myenv/lib/python3.14/site-packages (from scikit-learn) (1.5.3)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (8.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 2.6 MB/s  0:00:03m 2.7 MB/s eta 0:00:01
# Downloading scipy-1.17.1-cp314-cp314-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 1.9 MB/s  0:00:18 eta 0:00:010:01:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [scikit-learn]━━━━━ 2/3 [scikit-learn]
# Successfully installed scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0

# %%
documentA = 'Jupiter is the largest Planet'
documentB = 'Mars is the fourth planet from the Sun'

# %%
#Create bag of words

# %%
bagOfWordsA = documentA.split(' ')
bagOfWordsB = documentB.split(' ')

# %%
#create collection of unique words from document A and B

# %%
uniqueWords = set(bagOfWordsA).union(set(bagOfWordsB))

# %%
# Create a dictionary of words and their occurence for each document in the corpus

# %%
numOfWordsA = dict.fromkeys(uniqueWords, 0)

for word in bagOfWordsA:
    numOfWordsA [word] += 1
    numOfWordsB = dict. fromkeys (uniqueWords, 0)

for word in bagOfWordsB:
    numOfWordsB[word] += 1

# %%
def computeTF(wordDict, bagOfWord

tfDict= ()

bagOfWordsCount = len (bagOfWords)

for word, count in wordDict.items ():

T

tfDict [word] count / float (bagofWordsCount)

return tfDict

tfA= computeTF (numOfWordsA, bag0fWordsA)

tfB = computeTF (numOfWordsB, bagOfWordsB)
